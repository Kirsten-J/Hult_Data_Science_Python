# %% [markdown]
# <h1> ORIGINAL PARAGRAPH </h1>
# <br>
# <h5>Hey everyone! We are team 12. We like to add a bit of fun to all of our assignments, so we decided that everyone would write about their favorite movie in one or two sentences. </h5>
#
# <h5>Kirsten: </h5><p> Tangled: A young girl joins a thief on a quest to visit the castle, and subsequently finds out she is a princess who was kidnapped at birth. <img src = "https://upload.wikimedia.org/wikipedia/en/a/a8/Tangled_poster.jpg" style="width:300px;height:400px;"> </p>
# <h5>Noah:</h5><p> Goodfellas: A young Leonardo DiCaprio is enthralled with and joins the Italian mafia in an attempt to live a luxurious and highbrow lifestyle but eventually gets caught. <img src = "https://m.media-amazon.com/images/I/81NuuGhiNmL._SL1500_.jpg" style="width:300px;height:400px;"> </p>
# <h5>Syed:</h5><p> Remember the Titans: A recently integrated high school football team attempts to renew their winning ways and unite under their new coach to win the championship. <img src = "https://m.media-amazon.com/images/M/MV5BYThkMzgxNjEtMzFiOC00MTI0LWI5MDItNDVmYjA4NzY5MDQ2L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg" style="width:300px;height:400px;"> </p>
# <h5>Carlos: </h5><p>Lion King: An orphaned little prince has to survive alone after the death of his father, he has to regain the kingship for the good of the people. <img src = "https://images-na.ssl-images-amazon.com/images/I/A1EuV1bxWLL.jpg" style="width:300px;height:400px;"> </p>
# <h5>Oreoluwa:</h5><p> Tom & Jerry: Jerry’s pranks are wildly hilarious and innovative, he definitely knows how to keep Tom’s life interesting. <img src = "https://thecentraltrend.com/wp-content/uploads/2021/03/tom-and-jerry-movie-poster.jpg)" style="width:300px;height:400px;"> </p>
# <h5>Yusuf: </h5><p>Fast and Furious: In a city rife with secret agents, heists, and illegal racing, the gang, led by Dominic Torreto, attempt a major robbery but must go up against the police department. <img src = "https://upload.wikimedia.org/wikipedia/en/8/8f/Fast_and_Furious_Poster.jpg" style="width:300px;height:400px;"> </p>
#
# <h1> DYNAMIC PARAGRAPH </h1>

# %%
# DYNAMIC PARAGRAPH

#introduction to the activity
print("""Directions
We will be creating a story using words you decide should be included. 
Within the story there are blank words that will be filled with the words 
you choose. Please follow directions as if you do not write the type of word 
that is needed the story will not make sense. """,
      end="\n \n")




#ask for inputs for the dynamic story

#ask for a profession
thief = input(prompt="Write a profession: ")
#ask for an actor's name
LeonardoDiCaprio = input(prompt="Write the name of an actor/actress: ")
#ask for a collective noun
mafia = input(prompt="Write a collective noun (plural noun): ")
#ask for a verb (ing)
football = input(prompt="Write a verb ending in -ing: ")
#ask for an adjective
orphaned = input(prompt="Write an adjective: ")
#ask for a plural noun
pranks = input(prompt="Write a plural noun: ")
#ask for an adjective
interesting = input(prompt="Write an adjective: ")
#ask for an adjective
illegal = input(prompt="Write an adjective: ")
#ask for a verb
goup = input(prompt="Write a verb (eg. sit):  ")
#ask for a verb in past tense
kidnapped = input(prompt="Write a past tense verb (walked):  ")





#write the story with the dynamic content
print(f""" 
Here's your story: 

Hey everyone! We are team 12. We like to add a bit of fun to all of our 
assignments, so we decided that everyone would write about their favorite movie in one or two sentences. 

Kirsten: Tangled: A young girl joins a {thief} on a quest to visit the castle, 
and subsequently finds out she is a princess who was {kidnapped} at birth. 

Noah: Goodfellas: A young {LeonardoDiCaprio} is enthralled with and joins the 
Italian {mafia} in an attempt to live a luxurious and highbrow lifestyle but 
eventually gets caught.

Syed: Remember the Titans: A recently integrated high school {football} team 
attempts to renew their winning ways and unite under their new coach to win 
the championship.

Carlos: Lion king: A(n) {orphaned} little prince has to survive alone after 
the death of his father, he has to regain the kingship for the good of the 
people.

Oreoluwa: Tom & Jerry: Jerry's {pranks} are wildly hilarious and innovative, 
he definitely knows how to keep Tom’s life {interesting}.

Yusuf: In a city rife with secret agents, heists, and {illegal} racing, the 
gang, led by Dominic Torreto, attempt a major robbery but must {goup} against 
the police department.
""",
      end="\n \n")
# Out:
# Directions
# We will be creating a story using words you decide should be included.
# Within the story there are blank words that will be filled with the words
# you choose. Please follow directions as if you do not write the type of word
# that is needed the story will not make sense.
#
# Write a profession: 4
# Write the name of an actor/actress: 4
# Write a collective noun (plural noun): 4
# Write a verb ending in -ing: 4
# Write an adjective: 4
# Write a plural noun: 4
# Write an adjective: 4
# Write an adjective: 4
# Write a verb (eg. sit):  4
# Write a past tense verb (walked):  4
#
# Here's your story:
#
#
# Hey everyone! We are team 12. We like to add a bit of fun to all of our
# assignments, so we decided that everyone would write about their favorite movie in one or two sentences.
#
# Kirsten: Tangled: A young girl joins a 4 on a quest to visit the castle,
# and subsequently finds out she is a princess who was 4 at birth.
#
# ...
